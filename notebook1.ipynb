# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('/Users/mac/Downloads/nature img.jpeg')
img=cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
res = cv2.resize(img, dsize=(140, 140), interpolation=cv2.INTER_AREA)
plt.subplot(1,2,1)
plt.imshow(res)
plt.subplot(1,2,2)
plt.imshow(img)
plt.show()
